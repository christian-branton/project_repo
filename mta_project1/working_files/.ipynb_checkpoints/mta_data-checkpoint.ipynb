# %% [markdown]
# ## Read Data to Dataframe

# %%
import pandas as pd
import numpy as np

# %%
# Import data
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [181201, 181208, 181215, 181222, 181229,
             190105, 190112, 190119, 190126, 
             190202, 190209, 190216, 190223,
             190302, 190309, 190316, 190323, 190330]
turnstiles_df = get_data(week_nums)
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/24/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/24/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/24/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/24/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  11/24/2018  19:00:00
#
#          DESC  ENTRIES  \
# 0     REGULAR  6845468
# 1  RECOVR AUD  6845479
# 2  RECOVR AUD  6845578
# 3  RECOVR AUD  6845780
# 4     REGULAR  6846083
#
#    EXITS
# 0                                            2321627
# 1                                            2321635
# 2                                            2321702
# 3                                            2321753
# 4                                            2321818

# %% [markdown]
# ## Clean Data (Part 1)

# %%
# Remove duplicate entries
turnstiles_df.sort_values(['C/A', 'UNIT', 'SCP', 'STATION', 'DATE', 'TIME'], inplace=True, ascending=False)
turnstiles_df.drop_duplicates(subset=['C/A', 'UNIT', 'SCP', 'STATION', 'DATE', 'TIME'], inplace=True)

# %%
# Convert date to datetime
turnstiles_df['DATE'] = pd.to_datetime(turnstiles_df['DATE'], format='%m/%d/%Y')
turnstiles_df.dtypes
# Out:
# C/A                                                                             object
# UNIT                                                                            object
# SCP                                                                             object
# STATION                                                                         object
# LINENAME                                                                        object
# DIVISION                                                                        object
# DATE                                                                    datetime64[ns]
# TIME                                                                            object
# DESC                                                                            object
# ENTRIES                                                                          int64
# EXITS                                                                            int64
# dtype: object

# %%
# Test for duplicate counts
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE", "TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)
 ['ENTRIES']).nunique()
# Out:
# 1

# %% [markdown]
# ## Calculate Entries per Day

# %%
# Get entries per day
entries_df = \
    (turnstiles_df.sort_values(by=['TIME'], ascending=False)
                  .groupby(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DATE'], as_index=False)
                  ['ENTRIES']
                  .first())

entries_df['DAILY_ENTRIES'] = (entries_df.groupby(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME'])
                                         ['ENTRIES']
                                         .diff()
                                         .shift(-1))

entries_df.head(5)
# Out:
#     C/A  UNIT       SCP STATION LINENAME       DATE  ENTRIES  DAILY_ENTRIES
# 0  A002  R051  02-00-00   59 ST  NQR456W 2018-11-24  6846261          740.0
# 1  A002  R051  02-00-00   59 ST  NQR456W 2018-11-25  6847001         1386.0
# 2  A002  R051  02-00-00   59 ST  NQR456W 2018-11-26  6848387         1426.0
# 3  A002  R051  02-00-00   59 ST  NQR456W 2018-11-27  6849813         1420.0
# 4  A002  R051  02-00-00   59 ST  NQR456W 2018-11-28  6851233         1537.0

# %% [markdown]
# ## Clean Data (Part 2)

# %%
# Invert neagative numbers and outliers
entries_df['DAILY_ENTRIES'] = entries_df['DAILY_ENTRIES'].abs()
entries_df[entries_df['DAILY_ENTRIES'] > 8000] = np.nan

# %% [markdown]
# ## Combine Station and Linename into a Single Variable (where necessary)

# %%
separate_stations = ['23 ST', '86 ST']
df1 = entries_df[entries_df['STATION'].isin(separate_stations)]
df1['STATION_LINE'] = df1['STATION'] + ' ' + df1['LINENAME']
df1.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         C/A  UNIT       SCP STATION LINENAME       DATE    ENTRIES  \
# 11989  A030  R083  01-00-00   23 ST      NRW 2018-11-24  6931107.0
# 11990  A030  R083  01-00-00   23 ST      NRW 2018-11-25  6932157.0
# 11991  A030  R083  01-00-00   23 ST      NRW 2018-11-26  6934404.0
# 11992  A030  R083  01-00-00   23 ST      NRW 2018-11-27  6936779.0
# 11993  A030  R083  01-00-00   23 ST      NRW 2018-11-28  6939222.0
#
#        DAILY_ENTRIES STATION_LINE
# 11989         1050.0    23 ST NRW
# 11990         2247.0    23 ST NRW
# 11991         2375.0    23 ST NRW
# 11992         2443.0    23 ST NRW
# 11993         2435.0    23 ST NRW

# %%
df2 = entries_df[~entries_df.STATION.isin(separate_stations)]
df2['STATION_LINE'] = df2['STATION']
df2.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     C/A  UNIT       SCP STATION LINENAME       DATE    ENTRIES  DAILY_ENTRIES  \
# 0  A002  R051  02-00-00   59 ST  NQR456W 2018-11-24  6846261.0          740.0
# 1  A002  R051  02-00-00   59 ST  NQR456W 2018-11-25  6847001.0         1386.0
# 2  A002  R051  02-00-00   59 ST  NQR456W 2018-11-26  6848387.0         1426.0
# 3  A002  R051  02-00-00   59 ST  NQR456W 2018-11-27  6849813.0         1420.0
# 4  A002  R051  02-00-00   59 ST  NQR456W 2018-11-28  6851233.0         1537.0
#
#   STATION_LINE
# 0        59 ST
# 1        59 ST
# 2        59 ST
# 3        59 ST
# 4        59 ST

# %%
entries_df = pd.concat([df1, df2], axis=0)
entries_df.sample(10)
# Out:
#           C/A  UNIT       SCP          STATION LINENAME       DATE  \
# 459556   R228  R143  00-00-01            28 ST        6 2019-01-23
# 19123    A041  R086  00-00-04        PRINCE ST      NRW 2019-02-10
# 509585   R317  R408  01-05-00       SIMPSON ST       25 2019-03-02
# 23133    A046  R463  00-06-05         CANAL ST  JNQRZ6W 2019-01-21
# 461252   R231  R176  00-00-02            33 ST        6 2019-01-21
# 309121   N545  R204  01-06-00        CHURCH AV       FG 2018-12-02
# 346965  PTH05  R543  00-04-09   EXCHANGE PLACE        1 2019-01-09
# 543379   R515  R095  00-00-03  ASTORIA DITMARS      NQW 2019-02-25
# 603787  TRAM2  R469  00-03-00    RIT-ROOSEVELT        R 2019-02-10
# 116829   J037  R009  00-00-00           121 ST       JZ 2019-03-08
#
#              ENTRIES  DAILY_ENTRIES     STATION_LINE
# 459556  1.427998e+09          720.0            28 ST
# 19123   8.634420e+06         1554.0        PRINCE ST
# 509585  1.174409e+08            0.0       SIMPSON ST
# 23133   5.499640e+05          393.0         CANAL ST
# 461252  1.227702e+07         1246.0            33 ST
# 309121  1.186452e+08          847.0        CHURCH AV
# 346965  0.000000e+00            0.0   EXCHANGE PLACE
# 543379  1.842857e+06            0.0  ASTORIA DITMARS
# 603787  6.432680e+05          192.0    RIT-ROOSEVELT
# 116829  3.348447e+06           17.0           121 ST

# %% [markdown]
# ## Get Top *N* Busiest Stations

# %%
# Get total entries per day by station
top_count = 50
per_station = (entries_df.groupby(['STATION_LINE'], as_index=False)
                         ['DAILY_ENTRIES']
                         .sum()
                         .sort_values(by=['DAILY_ENTRIES'], ascending=False))
tops_df = per_station.head(top_count).reset_index().drop(['index'], axis=1)
tops_df['DAILY_ENTRIES'] = tops_df['DAILY_ENTRIES'] / len(entries_df['DATE'].dropna().unique())
tops_df
# Out:
#        STATION_LINE  DAILY_ENTRIES
# 0    34 ST-PENN STA  140962.944444
# 1   GRD CNTRL-42 ST  123142.388889
# 2   34 ST-HERALD SQ  106517.166667
# 3   42 ST-PORT AUTH   88229.436508
# 4    14 ST-UNION SQ   87101.928571
# 5    TIMES SQ-42 ST   84867.158730
# 6         FULTON ST   76393.039683
# 7            125 ST   66145.000000
# 8          CANAL ST   62808.865079
# 9    59 ST COLUMBUS   61940.031746
# 10            59 ST   55459.174603
# 11            96 ST   53209.222222
# 12            14 ST   53039.452381
# 13   47-50 STS ROCK   52044.880952
# 14    FLUSHING-MAIN   47600.119048
# 15      CHAMBERS ST   47065.460317
# 16            50 ST   43088.357143
# 17  JKSN HT-ROOSVLT   42731.968254
# 18     PATH NEW WTC   42634.436508
# 19            72 ST   40017.452381
# 20   ATL AV-BARCLAY   38787.833333
# 21        86 ST 456   35766.674603
# 22   W 4 ST-WASH SQ   35728.841270
# 23  42 ST-BRYANT PK   34501.698413
# 24  JAY ST-METROTEC   34292.404762
# 25  LEXINGTON AV/53   33739.849206
# 26          WALL ST   33180.388889
# 27             7 AV   33081.730159
# 28            28 ST   32784.936508
# 29       57 ST-7 AV   31100.444444
# 30           145 ST   30786.166667
# 31        CHURCH AV   30486.809524
# 32             8 AV   29345.111111
# 33     BOROUGH HALL   28249.365079
# 34        DEKALB AV   27753.500000
# 35           116 ST   27692.738095
# 36   JAMAICA CENTER   27361.214286
# 37           103 ST   25723.277778
# 38         GRAND ST   25660.539683
# 39            33 ST   25618.444444
# 40            77 ST   25390.309524
# 41      72 ST-2 AVE   25369.309524
# 42          23 ST 6   24991.158730
# 43   DELANCEY/ESSEX   22477.674603
# 44      86 ST-2 AVE   22450.158730
# 45    BOWLING GREEN   22449.603175
# 46        KINGS HWY   22315.674603
# 47  FOREST HILLS 71   22292.087302
# 48      KEW GARDENS   21524.666667
# 49  CROWN HTS-UTICA   21426.658730

# %% [markdown]
# ## Check Data with Graphs

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(10, 10))
tops_display_df = tops_df.sort_values(by='DAILY_ENTRIES')
plt.barh(tops_display_df['STATION_LINE'], tops_display_df['DAILY_ENTRIES']);

# %%
tops_mask = entries_df['STATION_LINE'].isin(tops_df['STATION_LINE'])
tops_daily = entries_df[tops_mask]
plt.figure(figsize=(10, 10))
sns.boxplot('DAILY_ENTRIES', 'STATION', data=tops_daily);

# %% [markdown]
# ## Format Station Names for Lat/Long Dataframe

# %%
latlong_df = pd.read_csv('https://data.ny.gov/api/views/i9wp-a4ja/rows.csv?accessType=DOWNLOAD')

# %%
latlong_df.columns
# Out:
# Index(['Division', 'Line', 'Station Name', 'Station Latitude',
#        'Station Longitude', 'Route1', 'Route2', 'Route3', 'Route4', 'Route5',
#        'Route6', 'Route7', 'Route8', 'Route9', 'Route10', 'Route11',
#        'Entrance Type', 'Entry', 'Exit Only', 'Vending', 'Staffing',
#        'Staff Hours', 'ADA', 'ADA Notes', 'Free Crossover',
#        'North South Street', 'East West Street', 'Corner', 'Entrance Latitude',
#        'Entrance Longitude', 'Station Location', 'Entrance Location'],
#       dtype='object')

# %%
latlong_df['Lines'] = ''
for x in range(1, 12):
    latlong_df['Lines'] += latlong_df[f'Route{x}'].fillna('').astype(str)
latlong_df.sample(5)
# Out:
#      Division       Line                             Station Name  \
# 380       IND  Archer Av  Parsons Blvd-Archer Av - Jamaica Center
# 554       BMT   Broadway                             Whitehall St
# 462       BMT   Broadway                                  23rd St
# 1262      IRT      Lenox                                 125th St
# 1376      IRT  Lexington                            Bowling Green
#
#       Station Latitude  Station Longitude Route1 Route2 Route3 Route4 Route5  \
# 380          40.702147         -73.801109      E      J      Z    NaN    NaN
# 554          40.703087         -74.012994      R      1    NaN    NaN    NaN
# 462          40.741303         -73.989344      N      R    NaN    NaN    NaN
# 1262         40.807754         -73.945495      2      3    NaN    NaN    NaN
# 1376         40.704817         -74.014065      4      5    NaN    NaN    NaN
#
#       ...  ADA Notes Free Crossover  North South Street  East West Street  \
# 380   ...        NaN           True        Parsons Blvd        Archer Ave
# 554   ...        NaN           True                 NaN               NaN
# 462   ...        NaN          False            Broadway           23rd St
# 1262  ...        NaN          False           Lenox Ave          125th St
# 1376  ...        NaN           True            Broadway        Battery Pl
#
#       Corner  Entrance Latitude Entrance Longitude         Station Location  \
# 380       NE          40.702821         -73.799843  (40.702147, -73.801109)
# 554      NaN          40.704015         -74.013284  (40.703087, -74.012994)
# 462       NW          40.741913         -73.989428  (40.741303, -73.989344)
# 1262      SE          40.807548         -73.945463  (40.807754, -73.945495)
# 1376      NW          40.704825         -74.014572  (40.704817, -74.014065)
#
#             Entrance Location Lines
# 380   (40.702821, -73.799843)   EJZ
# 554   (40.704015, -74.013284)    R1
# 462   (40.741913, -73.989428)    NR
# 1262  (40.807548, -73.945463)    23
# 1376  (40.704825, -74.014572)    45
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Merge MTA Turnstile and Station Info Dataframes

# %%
latlong_names_df = pd.read_csv('latlong_names.csv')
latlong_names_df['STATION_LINE'].value_counts().head(5)
# Out:
# BEVERLEY ROAD    1
# 14TH STREET 1    1
# 57 ST-7 AV       1
# 9 AV             1
# NEREID AV        1
# Name: STATION_LINE, dtype: int64

# %%
all_mta_df = tops_df.merge(latlong_names_df, on='STATION_LINE', how='left')
#all_mta_df

# %%
latlong_means_df = latlong_df.groupby(['Station Name'])['Station Latitude', 'Station Longitude'].mean()
all_mta_df = all_mta_df.merge(latlong_means_df, left_on='LL_NAME', right_on='Station Name', how='left')
all_mta_df
# Out:
#        STATION_LINE  DAILY_ENTRIES                                  LL_NAME  \
# 0    34 ST-PENN STA     17705633.0                                  34th St
# 1   GRD CNTRL-42 ST     15472550.0                    Grand Central-42nd St
# 2   34 ST-HERALD SQ     13377929.0                                  34th St
# 3   42 ST-PORT AUTH     11061713.0                                  42nd St
# 4    14 ST-UNION SQ     10936479.0                     14th St-Union Square
# 5    TIMES SQ-42 ST     10641226.0                             Times Square
# 6         FULTON ST      9595345.0                                Fulton St
# 7            125 ST      8301242.0                                 125th St
# 8          CANAL ST      7880639.0                                 Canal St
# 9    59 ST COLUMBUS      7770388.0                                  59th St
# 10            59 ST      6970574.0                                  59th St
# 11            96 ST      6682137.0                                  96th St
# 12            14 ST      6657571.0                                  14th St
# 13   47-50 STS ROCK      6531964.0           47-50th Sts Rockefeller Center
# 14    FLUSHING-MAIN      5970041.0                         Flushing-Main St
# 15      CHAMBERS ST      5922537.0                              Chambers St
# 16            50 ST      5401234.0                                  50th St
# 17  JKSN HT-ROOSVLT      5361013.0            Jackson Heights-Roosevelt Ave
# 18     PATH NEW WTC      5355765.0                                      NaN
# 19            72 ST      5017403.0                                  72nd St
# 20   ATL AV-BARCLAY      4866229.0                 Atlantic Av-Barclays Ctr
# 21        86 ST 456      4491806.0                                  86th St
# 22   W 4 ST-WASH SQ      4481498.0                              West 4th St
# 23  42 ST-BRYANT PK      4328462.0                                  42nd St
# 24  JAY ST-METROTEC      4310852.0                    Jay St - Borough Hall
# 25  LEXINGTON AV/53      4242535.0                     Lexington Av-53rd St
# 26          WALL ST      4174567.0                                  Wall St
# 27             7 AV      4152099.0                                   7th Av
# 28            28 ST      4131251.0                                  28th St
# 29       57 ST-7 AV      3906529.0                                  57th St
# 30           145 ST      3862698.0                                 145th St
# 31        CHURCH AV      3829729.0                                Church Av
# 32             8 AV      3676169.0                                   8th Av
# 33     BOROUGH HALL      3551690.0                             Borough Hall
# 34        DEKALB AV      3484258.0                                DeKalb Av
# 35           116 ST      3473348.0                                 116th St
# 36   JAMAICA CENTER      3444604.0  Parsons Blvd-Archer Av - Jamaica Center
# 37           103 ST      3225577.0                                 103rd St
# 38            33 ST      3216279.0                                  33rd St
# 39         GRAND ST      3215132.0                                 Grand St
# 40            77 ST      3189420.0                                  77th St
# 41      72 ST-2 AVE      3186710.0                                      NaN
# 42          23 ST 6      3141473.0                                  23rd St
# 43    BOWLING GREEN      2820080.0                            Bowling Green
# 44   DELANCEY/ESSEX      2818985.0                              Delancey St
# 45      86 ST-2 AVE      2817115.0                                      NaN
# 46        KINGS HWY      2802934.0                            Kings Highway
# 47  FOREST HILLS 71      2799957.0                     Forest Hills-71st Av
# 48      KEW GARDENS      2704673.0               Kew Gardens-Union Turnpike
# 49  CROWN HTS-UTICA      2690175.0                                 Utica Av
#
#     Station Latitude  Station Longitude
# 0          40.750882         -73.990876
# 1          40.751738         -73.976758
# 2          40.750882         -73.990876
# 3          40.755765         -73.987152
# 4          40.734673         -73.989951
# 5          40.755359         -73.987368
# 6          40.707411         -74.004122
# 7          40.809510         -73.948289
# 8          40.720309         -74.003088
# 9          40.736216         -73.986555
# 10         40.736216         -73.986555
# 11         40.790857         -73.964024
# 12         40.738924         -73.999124
# 13         40.758663         -73.981329
# 14         40.759600         -73.830030
# 15         40.714489         -74.008137
# 16         40.736998         -73.987105
# 17         40.746644         -73.891338
# 18               NaN                NaN
# 19         40.777228         -73.979587
# 20         40.684012         -73.978238
# 21         40.753149         -73.974264
# 22         40.732338         -74.000495
# 23         40.755765         -73.987152
# 24         40.692338         -73.987342
# 25         40.757552         -73.969055
# 26         40.707242         -74.010678
# 27         40.695408         -73.979552
# 28         40.745103         -73.988518
# 29         40.764318         -73.979054
# 30         40.823849         -73.943181
# 31         40.648080         -73.963404
# 32         40.704873         -74.005625
# 33         40.692766         -73.990083
# 34         40.698164         -73.945596
# 35         40.801937         -73.948708
# 36         40.702147         -73.801109
# 37         40.781165         -73.929092
# 38         40.746081         -73.982076
# 39         40.714644         -73.963420
# 40         40.734381         -73.977775
# 41               NaN                NaN
# 42         40.742838         -73.992445
# 43         40.704817         -74.014065
# 44         40.718611         -73.988114
# 45               NaN                NaN
# 46         40.605192         -73.969261
# 47         40.721691         -73.844521
# 48         40.714441         -73.831008
# 49         40.672703         -73.932137

# %% [markdown]
# ## Write out .csv

# %%
all_mta_df.to_csv('mta_busiest_latlong.csv')
